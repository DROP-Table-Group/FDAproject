# %%
import polars as pl
from polars import col, lit
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pl.read_csv("../data/cleaned_rv_daily.csv")

# %%
data = data.with_columns([
    col("Date").str.strptime(pl.Date, format="%Y/%m/%d").alias("Date")
])

# %%
data
# Out:
# shape: (4_713, 2)
# ┌────────────┬───────────┐
# │ Date       ┆ rv        │
# │ ---        ┆ ---       │
# │ date       ┆ f64       │
# ╞════════════╪═══════════╡
# │ 2012-08-03 ┆ 0.040338  │
# │ 2012-08-04 ┆ 0.011511  │
# │ 2012-08-05 ┆ 0.008317  │
# │ 2012-08-06 ┆ 0.003789  │
# │ 2012-08-07 ┆ 0.0008    │
# │ …          ┆ …         │
# │ 2026-01-14 ┆ 0.000445  │
# │ 2026-01-15 ┆ 0.000419  │
# │ 2026-01-16 ┆ 0.000218  │
# │ 2026-01-17 ┆ 0.0000391 │
# │ 2026-01-18 ┆ 0.0000993 │
# └────────────┴───────────┘
